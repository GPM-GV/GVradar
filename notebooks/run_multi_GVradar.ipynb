# %% [markdown]
# # GVradar - Multi Processing Example #
#
# ### Global Precipitation Measurement (GPM) Ground Validation (GV) radar processing software (GVradar).
#
# * Python based Dual Pol Quality Control (DPQC), utilizing the Python Atmospheric Radiation Measurement (ARM) Radar Toolkit (Py-ART) and CSU Radar Tools.
# * Precipitation product generation from Dual Pol, utilizing the Python Atmospheric Radiation Measurement (ARM) Radar Toolkit (Py-ART) and CSU Radar Tools.
# * Developed by the NASA GPM-GV group
# * V0.4 - 04/22/2021 - update by Jason Pippitt NASA/GSFC/SSAI
#
# ### Use run_multi_GVradar.py when processing large data sets.  Jobs are sent to individual processors to speed up processing.
#
# ### Notebook is for learning purposes.  Operationally, GVradar will be run from the command line, see README.

# %% [markdown]
# ### Run program with help flag to view user details.

# %%
# !python run_multi_GVradar.py --help
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
#
# /home/trmmgv/anaconda3/lib/python3.7/site-packages/fsspec/__init__.py:47: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for spec in entry_points.get("fsspec.specs", []):
# Done.
#
# usage: run_multi_GVradar.py [-h] [--stime STIME [STIME ...]]
#                             [--etime ETIME [ETIME ...]]
#                             [--thresh_dict THRESH_DICT]
#                             [--product_dict PRODUCT_DICT] [--do_qc]
#                             [--dp_products]
#                             in_dir
#
# User information
#
# positional arguments:
#   in_dir                Input Directory
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --stime STIME [STIME ...]
#                         Year Month Day Hour Minute ex: 2020 1 1 0 59
#   --etime ETIME [ETIME ...]
#                         Year, Month, Day, Hour, Minute ex: 2020 1 1 23 59
#   --thresh_dict THRESH_DICT
#                         Threshold dictionary
#   --product_dict PRODUCT_DICT
#                         DP product dictionary
#   --do_qc               Run QC
#   --dp_products         Create DP products

# %% [markdown]
# ### First, lets run with only one file.  We will run QC and DP_products with CF output and plots.  Run time is 1.6 minutes.

# %%
# !python run_multi_GVradar.py /gpmraid/raw/NPOL/Newark/ --stime 2020 10 29 15 0 --etime 2020 10 29 15 5 --do_qc --thresh_dict ../VN_dict-1.txt --dp_products --product_dict ../DP_product_dict.txt
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
#
# /home/trmmgv/anaconda3/lib/python3.7/site-packages/fsspec/__init__.py:47: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for spec in entry_points.get("fsspec.specs", []):
# Done.
#
# ['/gpmraid/raw/NPOL/Newark//2020/1029/ppi/np1201029150032.RAWNRB2.gz']
#
# QC parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '00', 'ss': '51', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'do_dbz': True, 'dbz_thresh': 5.0, 'do_rh': True, 'rh_thresh': 0.72, 'do_zdr': True, 'dr_min': -6.0, 'dr_max': 4.0, 'do_kdp': False, 'kdp_min': -2.0, 'kdp_max': 7.0, 'do_sq': False, 'sq_thresh': 0.45, 'do_sd': True, 'sd_thresh': 25.0, 'do_ph': False, 'ph_thresh': 80.0, 'do_ap': True, 'ap_dbz': 45, 'ap_zdr': 3, 'dealias_velocity': False, 'do_insect': False, 'do_despeckle': True, 'do_cos': False, 'coshmin': 0, 'coshmax': None, 'cosrmin': 0, 'cosrmax': 75, 'cosazmin': 0, 'cosazmax': 360, 'coselmin': 0, 'coselmax': 20.0, 'do_sector': False, 'sechmin': 0, 'sechmax': None, 'secrmin': 0, 'secrmax': 150, 'secazmin': 240, 'secazmax': 270, 'secelmin': 0, 'secelmax': 20.0, 'do_rh_sector': False, 'rhhmin': 0, 'rhhmax': None, 'rhrmin': 0, 'rhrmax': 150, 'rhazmin': 0, 'rhazmax': 360, 'rhelmin': 0, 'rhelmax': 20.0, 'rh_sec': 0.92, 'do_sd_sector': True, 'sdhmin': 0, 'sdhmax': None, 'sdrmin': 0, 'sdrmax': 60, 'sdazmin': 0, 'sdazmax': 360, 'sdelmin': 0, 'sdelmax': 7.0, 'sd_sec': 8.0, 'do_ph_sector': False, 'phhmin': 0, 'phhmax': None, 'phrmin': 0, 'phrmax': 150, 'phazmin': 160, 'phazmax': 165, 'phelmin': 0, 'phelmax': 20.0, 'ph_sec': 80.0, 'apply_cal': False, 'ref_cal': 0.2, 'zdr_cal': 0.0, 'use_qc_height': True, 'qc_height': 1.9, 'output_cf': False, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD'], 'cf_dir': './cf', 'plot_images': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'plot_single': False, 'fields_to_plot': ['DZ', 'CZ', 'DR', 'RH', 'KD', 'PH', 'SD', 'VR'], 'plot_dir': './plots', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> np1201029150032.RAWNRB2
#
# Renaming radar fields...
# dict_keys(['DBT2', 'DBTV16', 'DBZV16', 'SNR16', 'DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ'])
#
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_15UTC.txt
#
# Begin Quality Control:
#     Thresholding DP Fields...
#     Unfolding PhiDP...
#     Getting new Kdp...
#     Thresholding Cal Fields...
# QC Complete.
#
# Removing QC threshold fields...
#
# Plotting PPI images...
#   --> ./plots/NPOL_2020_1029_150051_8panel_sw00_PPI.png
#
# <pyart.core.radar.Radar object at 0x14d71e448e90>
#
# DP products parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '00', 'ss': '51', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'cf_dir': './cf/', 'do_HID': True, 'do_mass': True, 'do_RC': True, 'do_tokay_DSD': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'output_cf': True, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD', 'SQ', 'FH', 'RC', 'DM', 'NW'], 'plot_images': True, 'plot_single': False, 'fields_to_plot': ['CZ', 'DM', 'NW', 'FH', 'RC', 'MW', 'MI'], 'plot_dir': './plots/', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> QC_radar
#
# Renaming radar fields...
# dict_keys(['DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD'])
#
#
# Calculating DP products:
#     Calculating Drop-Size Distribution...
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_15UTC.txt
#     Add HID field to radar...
#     Calculating water and ice mass...
#     Calculating blended rainfall field...
# DP products complete.
#
# Plotting PPI images...
#   --> ./plots//NPOL_2020_1029_150051_7panel_sw00_PPI.png
#
# Removing unwanted output fields...
#
# CF FIELDS -->
# dict_keys(['DZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD', 'DM', 'NW', 'FH', 'RC'])
#
# Output cfRadial --> ./cf//NPOL_2020_1029_150051_PPI.cf.gz
#
# Run time was 1.6 minute(s)
#
# Done.

# %% [markdown]
# ### Now let's run with an hour of data.  Run time is only 2 minutes to run 9 files!

# %%
# !python run_multi_GVradar.py /gpmraid/raw/NPOL/Newark/ --stime 2020 10 29 15 0 --etime 2020 10 29 16 0 --do_qc --thresh_dict ../VN_dict-1.txt --dp_products --product_dict ../DP_product_dict.txt
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
#
# /home/trmmgv/anaconda3/lib/python3.7/site-packages/fsspec/__init__.py:47: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for spec in entry_points.get("fsspec.specs", []):
# Done.
#
# ['/gpmraid/raw/NPOL/Newark//2020/1029/ppi/np1201029150032.RAWNRB2.gz', '/gpmraid/raw/NPOL/Newark//2020/1029/ppi/np1201029150747.RAWNRB3.gz', '/gpmraid/raw/NPOL/Newark//2020/1029/ppi/np1201029151502.RAWNRB4.gz', '/gpmraid/raw/NPOL/Newark//2020/1029/ppi/np1201029152216.RAWNRB5.gz', '/gpmraid/raw/NPOL/Newark//2020/1029/ppi/np1201029152931.RAWNRB6.gz', '/gpmraid/raw/NPOL/Newark//2020/1029/ppi/np1201029153646.RAWNRB7.gz', '/gpmraid/raw/NPOL/Newark//2020/1029/ppi/np1201029154401.RAWNRB8.gz', '/gpmraid/raw/NPOL/Newark//2020/1029/ppi/np1201029155117.RAWNRB9.gz', '/gpmraid/raw/NPOL/Newark//2020/1029/ppi/np1201029155831.RAWNRBA.gz']
#
# QC parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '00', 'ss': '51', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'do_dbz': True, 'dbz_thresh': 5.0, 'do_rh': True, 'rh_thresh': 0.72, 'do_zdr': True, 'dr_min': -6.0, 'dr_max': 4.0, 'do_kdp': False, 'kdp_min': -2.0, 'kdp_max': 7.0, 'do_sq': False, 'sq_thresh': 0.45, 'do_sd': True, 'sd_thresh': 25.0, 'do_ph': False, 'ph_thresh': 80.0, 'do_ap': True, 'ap_dbz': 45, 'ap_zdr': 3, 'dealias_velocity': False, 'do_insect': False, 'do_despeckle': True, 'do_cos': False, 'coshmin': 0, 'coshmax': None, 'cosrmin': 0, 'cosrmax': 75, 'cosazmin': 0, 'cosazmax': 360, 'coselmin': 0, 'coselmax': 20.0, 'do_sector': False, 'sechmin': 0, 'sechmax': None, 'secrmin': 0, 'secrmax': 150, 'secazmin': 240, 'secazmax': 270, 'secelmin': 0, 'secelmax': 20.0, 'do_rh_sector': False, 'rhhmin': 0, 'rhhmax': None, 'rhrmin': 0, 'rhrmax': 150, 'rhazmin': 0, 'rhazmax': 360, 'rhelmin': 0, 'rhelmax': 20.0, 'rh_sec': 0.92, 'do_sd_sector': True, 'sdhmin': 0, 'sdhmax': None, 'sdrmin': 0, 'sdrmax': 60, 'sdazmin': 0, 'sdazmax': 360, 'sdelmin': 0, 'sdelmax': 7.0, 'sd_sec': 8.0, 'do_ph_sector': False, 'phhmin': 0, 'phhmax': None, 'phrmin': 0, 'phrmax': 150, 'phazmin': 160, 'phazmax': 165, 'phelmin': 0, 'phelmax': 20.0, 'ph_sec': 80.0, 'apply_cal': False, 'ref_cal': 0.2, 'zdr_cal': 0.0, 'use_qc_height': True, 'qc_height': 1.9, 'output_cf': False, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD'], 'cf_dir': './cf', 'plot_images': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'plot_single': False, 'fields_to_plot': ['DZ', 'CZ', 'DR', 'RH', 'KD', 'PH', 'SD', 'VR'], 'plot_dir': './plots', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> np1201029150032.RAWNRB2
#
# QC parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '37', 'ss': '09', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'do_dbz': True, 'dbz_thresh': 5.0, 'do_rh': True, 'rh_thresh': 0.72, 'do_zdr': True, 'dr_min': -6.0, 'dr_max': 4.0, 'do_kdp': False, 'kdp_min': -2.0, 'kdp_max': 7.0, 'do_sq': False, 'sq_thresh': 0.45, 'do_sd': True, 'sd_thresh': 25.0, 'do_ph': False, 'ph_thresh': 80.0, 'do_ap': True, 'ap_dbz': 45, 'ap_zdr': 3, 'dealias_velocity': False, 'do_insect': False, 'do_despeckle': True, 'do_cos': False, 'coshmin': 0, 'coshmax': None, 'cosrmin': 0, 'cosrmax': 75, 'cosazmin': 0, 'cosazmax': 360, 'coselmin': 0, 'coselmax': 20.0, 'do_sector': False, 'sechmin': 0, 'sechmax': None, 'secrmin': 0, 'secrmax': 150, 'secazmin': 240, 'secazmax': 270, 'secelmin': 0, 'secelmax': 20.0, 'do_rh_sector': False, 'rhhmin': 0, 'rhhmax': None, 'rhrmin': 0, 'rhrmax': 150, 'rhazmin': 0, 'rhazmax': 360, 'rhelmin': 0, 'rhelmax': 20.0, 'rh_sec': 0.92, 'do_sd_sector': True, 'sdhmin': 0, 'sdhmax': None, 'sdrmin': 0, 'sdrmax': 60, 'sdazmin': 0, 'sdazmax': 360, 'sdelmin': 0, 'sdelmax': 7.0, 'sd_sec': 8.0, 'do_ph_sector': False, 'phhmin': 0, 'phhmax': None, 'phrmin': 0, 'phrmax': 150, 'phazmin': 160, 'phazmax': 165, 'phelmin': 0, 'phelmax': 20.0, 'ph_sec': 80.0, 'apply_cal': False, 'ref_cal': 0.2, 'zdr_cal': 0.0, 'use_qc_height': True, 'qc_height': 1.9, 'output_cf': False, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD'], 'cf_dir': './cf', 'plot_images': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'plot_single': False, 'fields_to_plot': ['DZ', 'CZ', 'DR', 'RH', 'KD', 'PH', 'SD', 'VR'], 'plot_dir': './plots', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> np1201029153646.RAWNRB7
#
# QC parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '22', 'ss': '37', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'do_dbz': True, 'dbz_thresh': 5.0, 'do_rh': True, 'rh_thresh': 0.72, 'do_zdr': True, 'dr_min': -6.0, 'dr_max': 4.0, 'do_kdp': False, 'kdp_min': -2.0, 'kdp_max': 7.0, 'do_sq': False, 'sq_thresh': 0.45, 'do_sd': True, 'sd_thresh': 25.0, 'do_ph': False, 'ph_thresh': 80.0, 'do_ap': True, 'ap_dbz': 45, 'ap_zdr': 3, 'dealias_velocity': False, 'do_insect': False, 'do_despeckle': True, 'do_cos': False, 'coshmin': 0, 'coshmax': None, 'cosrmin': 0, 'cosrmax': 75, 'cosazmin': 0, 'cosazmax': 360, 'coselmin': 0, 'coselmax': 20.0, 'do_sector': False, 'sechmin': 0, 'sechmax': None, 'secrmin': 0, 'secrmax': 150, 'secazmin': 240, 'secazmax': 270, 'secelmin': 0, 'secelmax': 20.0, 'do_rh_sector': False, 'rhhmin': 0, 'rhhmax': None, 'rhrmin': 0, 'rhrmax': 150, 'rhazmin': 0, 'rhazmax': 360, 'rhelmin': 0, 'rhelmax': 20.0, 'rh_sec': 0.92, 'do_sd_sector': True, 'sdhmin': 0, 'sdhmax': None, 'sdrmin': 0, 'sdrmax': 60, 'sdazmin': 0, 'sdazmax': 360, 'sdelmin': 0, 'sdelmax': 7.0, 'sd_sec': 8.0, 'do_ph_sector': False, 'phhmin': 0, 'phhmax': None, 'phrmin': 0, 'phrmax': 150, 'phazmin': 160, 'phazmax': 165, 'phelmin': 0, 'phelmax': 20.0, 'ph_sec': 80.0, 'apply_cal': False, 'ref_cal': 0.2, 'zdr_cal': 0.0, 'use_qc_height': True, 'qc_height': 1.9, 'output_cf': False, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD'], 'cf_dir': './cf', 'plot_images': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'plot_single': False, 'fields_to_plot': ['DZ', 'CZ', 'DR', 'RH', 'KD', 'PH', 'SD', 'VR'], 'plot_dir': './plots', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> np1201029152216.RAWNRB5
#
# Renaming radar fields...
#
# Renaming radar fields...
#
# Renaming radar fields...
#
# QC parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '44', 'ss': '24', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'do_dbz': True, 'dbz_thresh': 5.0, 'do_rh': True, 'rh_thresh': 0.72, 'do_zdr': True, 'dr_min': -6.0, 'dr_max': 4.0, 'do_kdp': False, 'kdp_min': -2.0, 'kdp_max': 7.0, 'do_sq': False, 'sq_thresh': 0.45, 'do_sd': True, 'sd_thresh': 25.0, 'do_ph': False, 'ph_thresh': 80.0, 'do_ap': True, 'ap_dbz': 45, 'ap_zdr': 3, 'dealias_velocity': False, 'do_insect': False, 'do_despeckle': True, 'do_cos': False, 'coshmin': 0, 'coshmax': None, 'cosrmin': 0, 'cosrmax': 75, 'cosazmin': 0, 'cosazmax': 360, 'coselmin': 0, 'coselmax': 20.0, 'do_sector': False, 'sechmin': 0, 'sechmax': None, 'secrmin': 0, 'secrmax': 150, 'secazmin': 240, 'secazmax': 270, 'secelmin': 0, 'secelmax': 20.0, 'do_rh_sector': False, 'rhhmin': 0, 'rhhmax': None, 'rhrmin': 0, 'rhrmax': 150, 'rhazmin': 0, 'rhazmax': 360, 'rhelmin': 0, 'rhelmax': 20.0, 'rh_sec': 0.92, 'do_sd_sector': True, 'sdhmin': 0, 'sdhmax': None, 'sdrmin': 0, 'sdrmax': 60, 'sdazmin': 0, 'sdazmax': 360, 'sdelmin': 0, 'sdelmax': 7.0, 'sd_sec': 8.0, 'do_ph_sector': False, 'phhmin': 0, 'phhmax': None, 'phrmin': 0, 'phrmax': 150, 'phazmin': 160, 'phazmax': 165, 'phelmin': 0, 'phelmax': 20.0, 'ph_sec': 80.0, 'apply_cal': False, 'ref_cal': 0.2, 'zdr_cal': 0.0, 'use_qc_height': True, 'qc_height': 1.9, 'output_cf': False, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD'], 'cf_dir': './cf', 'plot_images': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'plot_single': False, 'fields_to_plot': ['DZ', 'CZ', 'DR', 'RH', 'KD', 'PH', 'SD', 'VR'], 'plot_dir': './plots', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> np1201029154401.RAWNRB8
#
# QC parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '29', 'ss': '53', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'do_dbz': True, 'dbz_thresh': 5.0, 'do_rh': True, 'rh_thresh': 0.72, 'do_zdr': True, 'dr_min': -6.0, 'dr_max': 4.0, 'do_kdp': False, 'kdp_min': -2.0, 'kdp_max': 7.0, 'do_sq': False, 'sq_thresh': 0.45, 'do_sd': True, 'sd_thresh': 25.0, 'do_ph': False, 'ph_thresh': 80.0, 'do_ap': True, 'ap_dbz': 45, 'ap_zdr': 3, 'dealias_velocity': False, 'do_insect': False, 'do_despeckle': True, 'do_cos': False, 'coshmin': 0, 'coshmax': None, 'cosrmin': 0, 'cosrmax': 75, 'cosazmin': 0, 'cosazmax': 360, 'coselmin': 0, 'coselmax': 20.0, 'do_sector': False, 'sechmin': 0, 'sechmax': None, 'secrmin': 0, 'secrmax': 150, 'secazmin': 240, 'secazmax': 270, 'secelmin': 0, 'secelmax': 20.0, 'do_rh_sector': False, 'rhhmin': 0, 'rhhmax': None, 'rhrmin': 0, 'rhrmax': 150, 'rhazmin': 0, 'rhazmax': 360, 'rhelmin': 0, 'rhelmax': 20.0, 'rh_sec': 0.92, 'do_sd_sector': True, 'sdhmin': 0, 'sdhmax': None, 'sdrmin': 0, 'sdrmax': 60, 'sdazmin': 0, 'sdazmax': 360, 'sdelmin': 0, 'sdelmax': 7.0, 'sd_sec': 8.0, 'do_ph_sector': False, 'phhmin': 0, 'phhmax': None, 'phrmin': 0, 'phrmax': 150, 'phazmin': 160, 'phazmax': 165, 'phelmin': 0, 'phelmax': 20.0, 'ph_sec': 80.0, 'apply_cal': False, 'ref_cal': 0.2, 'zdr_cal': 0.0, 'use_qc_height': True, 'qc_height': 1.9, 'output_cf': False, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD'], 'cf_dir': './cf', 'plot_images': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'plot_single': False, 'fields_to_plot': ['DZ', 'CZ', 'DR', 'RH', 'KD', 'PH', 'SD', 'VR'], 'plot_dir': './plots', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> np1201029152931.RAWNRB6
#
# QC parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '15', 'ss': '20', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'do_dbz': True, 'dbz_thresh': 5.0, 'do_rh': True, 'rh_thresh': 0.72, 'do_zdr': True, 'dr_min': -6.0, 'dr_max': 4.0, 'do_kdp': False, 'kdp_min': -2.0, 'kdp_max': 7.0, 'do_sq': False, 'sq_thresh': 0.45, 'do_sd': True, 'sd_thresh': 25.0, 'do_ph': False, 'ph_thresh': 80.0, 'do_ap': True, 'ap_dbz': 45, 'ap_zdr': 3, 'dealias_velocity': False, 'do_insect': False, 'do_despeckle': True, 'do_cos': False, 'coshmin': 0, 'coshmax': None, 'cosrmin': 0, 'cosrmax': 75, 'cosazmin': 0, 'cosazmax': 360, 'coselmin': 0, 'coselmax': 20.0, 'do_sector': False, 'sechmin': 0, 'sechmax': None, 'secrmin': 0, 'secrmax': 150, 'secazmin': 240, 'secazmax': 270, 'secelmin': 0, 'secelmax': 20.0, 'do_rh_sector': False, 'rhhmin': 0, 'rhhmax': None, 'rhrmin': 0, 'rhrmax': 150, 'rhazmin': 0, 'rhazmax': 360, 'rhelmin': 0, 'rhelmax': 20.0, 'rh_sec': 0.92, 'do_sd_sector': True, 'sdhmin': 0, 'sdhmax': None, 'sdrmin': 0, 'sdrmax': 60, 'sdazmin': 0, 'sdazmax': 360, 'sdelmin': 0, 'sdelmax': 7.0, 'sd_sec': 8.0, 'do_ph_sector': False, 'phhmin': 0, 'phhmax': None, 'phrmin': 0, 'phrmax': 150, 'phazmin': 160, 'phazmax': 165, 'phelmin': 0, 'phelmax': 20.0, 'ph_sec': 80.0, 'apply_cal': False, 'ref_cal': 0.2, 'zdr_cal': 0.0, 'use_qc_height': True, 'qc_height': 1.9, 'output_cf': False, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD'], 'cf_dir': './cf', 'plot_images': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'plot_single': False, 'fields_to_plot': ['DZ', 'CZ', 'DR', 'RH', 'KD', 'PH', 'SD', 'VR'], 'plot_dir': './plots', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> np1201029151502.RAWNRB4
#
# Renaming radar fields...
#
# QC parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '07', 'ss': '51', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'do_dbz': True, 'dbz_thresh': 5.0, 'do_rh': True, 'rh_thresh': 0.72, 'do_zdr': True, 'dr_min': -6.0, 'dr_max': 4.0, 'do_kdp': False, 'kdp_min': -2.0, 'kdp_max': 7.0, 'do_sq': False, 'sq_thresh': 0.45, 'do_sd': True, 'sd_thresh': 25.0, 'do_ph': False, 'ph_thresh': 80.0, 'do_ap': True, 'ap_dbz': 45, 'ap_zdr': 3, 'dealias_velocity': False, 'do_insect': False, 'do_despeckle': True, 'do_cos': False, 'coshmin': 0, 'coshmax': None, 'cosrmin': 0, 'cosrmax': 75, 'cosazmin': 0, 'cosazmax': 360, 'coselmin': 0, 'coselmax': 20.0, 'do_sector': False, 'sechmin': 0, 'sechmax': None, 'secrmin': 0, 'secrmax': 150, 'secazmin': 240, 'secazmax': 270, 'secelmin': 0, 'secelmax': 20.0, 'do_rh_sector': False, 'rhhmin': 0, 'rhhmax': None, 'rhrmin': 0, 'rhrmax': 150, 'rhazmin': 0, 'rhazmax': 360, 'rhelmin': 0, 'rhelmax': 20.0, 'rh_sec': 0.92, 'do_sd_sector': True, 'sdhmin': 0, 'sdhmax': None, 'sdrmin': 0, 'sdrmax': 60, 'sdazmin': 0, 'sdazmax': 360, 'sdelmin': 0, 'sdelmax': 7.0, 'sd_sec': 8.0, 'do_ph_sector': False, 'phhmin': 0, 'phhmax': None, 'phrmin': 0, 'phrmax': 150, 'phazmin': 160, 'phazmax': 165, 'phelmin': 0, 'phelmax': 20.0, 'ph_sec': 80.0, 'apply_cal': False, 'ref_cal': 0.2, 'zdr_cal': 0.0, 'use_qc_height': True, 'qc_height': 1.9, 'output_cf': False, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD'], 'cf_dir': './cf', 'plot_images': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'plot_single': False, 'fields_to_plot': ['DZ', 'CZ', 'DR', 'RH', 'KD', 'PH', 'SD', 'VR'], 'plot_dir': './plots', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> np1201029150747.RAWNRB3
#
# Renaming radar fields...
#
# Renaming radar fields...
#
# Renaming radar fields...
#
# QC parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '51', 'ss': '37', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'do_dbz': True, 'dbz_thresh': 5.0, 'do_rh': True, 'rh_thresh': 0.72, 'do_zdr': True, 'dr_min': -6.0, 'dr_max': 4.0, 'do_kdp': False, 'kdp_min': -2.0, 'kdp_max': 7.0, 'do_sq': False, 'sq_thresh': 0.45, 'do_sd': True, 'sd_thresh': 25.0, 'do_ph': False, 'ph_thresh': 80.0, 'do_ap': True, 'ap_dbz': 45, 'ap_zdr': 3, 'dealias_velocity': False, 'do_insect': False, 'do_despeckle': True, 'do_cos': False, 'coshmin': 0, 'coshmax': None, 'cosrmin': 0, 'cosrmax': 75, 'cosazmin': 0, 'cosazmax': 360, 'coselmin': 0, 'coselmax': 20.0, 'do_sector': False, 'sechmin': 0, 'sechmax': None, 'secrmin': 0, 'secrmax': 150, 'secazmin': 240, 'secazmax': 270, 'secelmin': 0, 'secelmax': 20.0, 'do_rh_sector': False, 'rhhmin': 0, 'rhhmax': None, 'rhrmin': 0, 'rhrmax': 150, 'rhazmin': 0, 'rhazmax': 360, 'rhelmin': 0, 'rhelmax': 20.0, 'rh_sec': 0.92, 'do_sd_sector': True, 'sdhmin': 0, 'sdhmax': None, 'sdrmin': 0, 'sdrmax': 60, 'sdazmin': 0, 'sdazmax': 360, 'sdelmin': 0, 'sdelmax': 7.0, 'sd_sec': 8.0, 'do_ph_sector': False, 'phhmin': 0, 'phhmax': None, 'phrmin': 0, 'phrmax': 150, 'phazmin': 160, 'phazmax': 165, 'phelmin': 0, 'phelmax': 20.0, 'ph_sec': 80.0, 'apply_cal': False, 'ref_cal': 0.2, 'zdr_cal': 0.0, 'use_qc_height': True, 'qc_height': 1.9, 'output_cf': False, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD'], 'cf_dir': './cf', 'plot_images': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'plot_single': False, 'fields_to_plot': ['DZ', 'CZ', 'DR', 'RH', 'KD', 'PH', 'SD', 'VR'], 'plot_dir': './plots', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> np1201029155117.RAWNRB9
# Renaming radar fields...
#
# QC parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '58', 'ss': '56', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'do_dbz': True, 'dbz_thresh': 5.0, 'do_rh': True, 'rh_thresh': 0.72, 'do_zdr': True, 'dr_min': -6.0, 'dr_max': 4.0, 'do_kdp': False, 'kdp_min': -2.0, 'kdp_max': 7.0, 'do_sq': False, 'sq_thresh': 0.45, 'do_sd': True, 'sd_thresh': 25.0, 'do_ph': False, 'ph_thresh': 80.0, 'do_ap': True, 'ap_dbz': 45, 'ap_zdr': 3, 'dealias_velocity': False, 'do_insect': False, 'do_despeckle': True, 'do_cos': False, 'coshmin': 0, 'coshmax': None, 'cosrmin': 0, 'cosrmax': 75, 'cosazmin': 0, 'cosazmax': 360, 'coselmin': 0, 'coselmax': 20.0, 'do_sector': False, 'sechmin': 0, 'sechmax': None, 'secrmin': 0, 'secrmax': 150, 'secazmin': 240, 'secazmax': 270, 'secelmin': 0, 'secelmax': 20.0, 'do_rh_sector': False, 'rhhmin': 0, 'rhhmax': None, 'rhrmin': 0, 'rhrmax': 150, 'rhazmin': 0, 'rhazmax': 360, 'rhelmin': 0, 'rhelmax': 20.0, 'rh_sec': 0.92, 'do_sd_sector': True, 'sdhmin': 0, 'sdhmax': None, 'sdrmin': 0, 'sdrmax': 60, 'sdazmin': 0, 'sdazmax': 360, 'sdelmin': 0, 'sdelmax': 7.0, 'sd_sec': 8.0, 'do_ph_sector': False, 'phhmin': 0, 'phhmax': None, 'phrmin': 0, 'phrmax': 150, 'phazmin': 160, 'phazmax': 165, 'phelmin': 0, 'phelmax': 20.0, 'ph_sec': 80.0, 'apply_cal': False, 'ref_cal': 0.2, 'zdr_cal': 0.0, 'use_qc_height': True, 'qc_height': 1.9, 'output_cf': False, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD'], 'cf_dir': './cf', 'plot_images': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'plot_single': False, 'fields_to_plot': ['DZ', 'CZ', 'DR', 'RH', 'KD', 'PH', 'SD', 'VR'], 'plot_dir': './plots', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> np1201029155831.RAWNRBA
# dict_keys(['DBT2', 'DBTV16', 'DBZV16', 'SNR16', 'DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ'])
#
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_15UTC.txt
# dict_keys(['DBT2', 'DBTV16', 'DBZV16', 'SNR16', 'DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ'])
#
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_16UTC.txt
# dict_keys(['DBT2', 'DBTV16', 'DBZV16', 'SNR16', 'DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ'])
#
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_15UTC.txt
#
# Renaming radar fields...
# dict_keys(['DBT2', 'DBTV16', 'DBZV16', 'SNR16', 'DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ'])
#
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_16UTC.txt
# dict_keys(['DBT2', 'DBTV16', 'DBZV16', 'SNR16', 'DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ'])
#
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_15UTC.txt
# dict_keys(['DBT2', 'DBTV16', 'DBZV16', 'SNR16', 'DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ'])
#
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_15UTC.txt
# dict_keys(['DBT2', 'DBTV16', 'DBZV16', 'SNR16', 'DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ'])
#
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_15UTC.txt
# dict_keys(['DBT2', 'DBTV16', 'DBZV16', 'SNR16', 'DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ'])
#
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_16UTC.txt
# dict_keys(['DBT2', 'DBTV16', 'DBZV16', 'SNR16', 'DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ'])
#
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_16UTC.txt
#
# Begin Quality Control:
#     Thresholding DP Fields...
#
# Begin Quality Control:
#     Thresholding DP Fields...
#
# Begin Quality Control:
#     Thresholding DP Fields...
#
# Begin Quality Control:
#     Thresholding DP Fields...
#
# Begin Quality Control:
#     Thresholding DP Fields...
#
# Begin Quality Control:
#     Thresholding DP Fields...
#
# Begin Quality Control:
#     Thresholding DP Fields...
#
# Begin Quality Control:
#     Thresholding DP Fields...
#
# Begin Quality Control:
#     Thresholding DP Fields...
#     Unfolding PhiDP...
#     Unfolding PhiDP...
#     Unfolding PhiDP...
#     Unfolding PhiDP...
#     Unfolding PhiDP...
#     Unfolding PhiDP...
#     Unfolding PhiDP...
#     Unfolding PhiDP...
#     Unfolding PhiDP...
#     Getting new Kdp...
#     Getting new Kdp...
#     Getting new Kdp...
#     Getting new Kdp...
#     Getting new Kdp...
#     Getting new Kdp...
#     Getting new Kdp...
#     Getting new Kdp...
#     Getting new Kdp...
#     Thresholding Cal Fields...
#     Thresholding Cal Fields...
#     Thresholding Cal Fields...
#     Thresholding Cal Fields...
#     Thresholding Cal Fields...
#     Thresholding Cal Fields...
#     Thresholding Cal Fields...
#     Thresholding Cal Fields...
#     Thresholding Cal Fields...
# QC Complete.
#
# Removing QC threshold fields...
#
# Plotting PPI images...
# QC Complete.
#
# Removing QC threshold fields...
#
# Plotting PPI images...
# QC Complete.
#
# Removing QC threshold fields...
#
# Plotting PPI images...
# QC Complete.
#
# Removing QC threshold fields...
#
# QC Complete.
#
# Removing QC threshold fields...
#
# Plotting PPI images...
# Plotting PPI images...
# QC Complete.
#
# Removing QC threshold fields...
#
# Plotting PPI images...
# QC Complete.
#
# Removing QC threshold fields...
#
# Plotting PPI images...
# QC Complete.
#
# Removing QC threshold fields...
#
# Plotting PPI images...
# QC Complete.
#
# Removing QC threshold fields...
#
# Plotting PPI images...
#   --> ./plots/NPOL_2020_1029_150051_8panel_sw00_PPI.png
#
#   --> ./plots/NPOL_2020_1029_151520_8panel_sw00_PPI.png
#
#   --> ./plots/NPOL_2020_1029_154424_8panel_sw00_PPI.png
#
#   --> ./plots/NPOL_2020_1029_153709_8panel_sw00_PPI.png
#
#   --> ./plots/NPOL_2020_1029_152237_8panel_sw00_PPI.png
#
#   --> ./plots/NPOL_2020_1029_150751_8panel_sw00_PPI.png
#
#   --> ./plots/NPOL_2020_1029_152953_8panel_sw00_PPI.png
#
#   --> ./plots/NPOL_2020_1029_155856_8panel_sw00_PPI.png
#
#   --> ./plots/NPOL_2020_1029_155137_8panel_sw00_PPI.png
#
# <pyart.core.radar.Radar object at 0x14ce329aa550>
# <pyart.core.radar.Radar object at 0x14ce32947950>
# <pyart.core.radar.Radar object at 0x14ce32a20750>
# <pyart.core.radar.Radar object at 0x14ce3293cf90>
#
# DP products parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '00', 'ss': '51', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'cf_dir': './cf/', 'do_HID': True, 'do_mass': True, 'do_RC': True, 'do_tokay_DSD': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'output_cf': True, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD', 'SQ', 'FH', 'RC', 'DM', 'NW'], 'plot_images': True, 'plot_single': False, 'fields_to_plot': ['CZ', 'DM', 'NW', 'FH', 'RC', 'MW', 'MI'], 'plot_dir': './plots/', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> QC_radar
#
# Renaming radar fields...
# <pyart.core.radar.Radar object at 0x14ce32962ad0>
# <pyart.core.radar.Radar object at 0x14ce329aa510>
#
# DP products parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '07', 'ss': '51', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'cf_dir': './cf/', 'do_HID': True, 'do_mass': True, 'do_RC': True, 'do_tokay_DSD': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'output_cf': True, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD', 'SQ', 'FH', 'RC', 'DM', 'NW'], 'plot_images': True, 'plot_single': False, 'fields_to_plot': ['CZ', 'DM', 'NW', 'FH', 'RC', 'MW', 'MI'], 'plot_dir': './plots/', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> QC_radar
#
# Renaming radar fields...
# <pyart.core.radar.Radar object at 0x14ce329aa410>
# <pyart.core.radar.Radar object at 0x14ce329aa150>
# <pyart.core.radar.Radar object at 0x14ce329a3dd0>
#
# DP products parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '22', 'ss': '37', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'cf_dir': './cf/', 'do_HID': True, 'do_mass': True, 'do_RC': True, 'do_tokay_DSD': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'output_cf': True, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD', 'SQ', 'FH', 'RC', 'DM', 'NW'], 'plot_images': True, 'plot_single': False, 'fields_to_plot': ['CZ', 'DM', 'NW', 'FH', 'RC', 'MW', 'MI'], 'plot_dir': './plots/', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> QC_radar
#
# Renaming radar fields...
#
# DP products parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '15', 'ss': '20', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'cf_dir': './cf/', 'do_HID': True, 'do_mass': True, 'do_RC': True, 'do_tokay_DSD': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'output_cf': True, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD', 'SQ', 'FH', 'RC', 'DM', 'NW'], 'plot_images': True, 'plot_single': False, 'fields_to_plot': ['CZ', 'DM', 'NW', 'FH', 'RC', 'MW', 'MI'], 'plot_dir': './plots/', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> QC_radar
#
# Renaming radar fields...
#
# DP products parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '29', 'ss': '53', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'cf_dir': './cf/', 'do_HID': True, 'do_mass': True, 'do_RC': True, 'do_tokay_DSD': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'output_cf': True, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD', 'SQ', 'FH', 'RC', 'DM', 'NW'], 'plot_images': True, 'plot_single': False, 'fields_to_plot': ['CZ', 'DM', 'NW', 'FH', 'RC', 'MW', 'MI'], 'plot_dir': './plots/', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> QC_radar
#
# Renaming radar fields...
#
# DP products parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '37', 'ss': '09', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'cf_dir': './cf/', 'do_HID': True, 'do_mass': True, 'do_RC': True, 'do_tokay_DSD': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'output_cf': True, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD', 'SQ', 'FH', 'RC', 'DM', 'NW'], 'plot_images': True, 'plot_single': False, 'fields_to_plot': ['CZ', 'DM', 'NW', 'FH', 'RC', 'MW', 'MI'], 'plot_dir': './plots/', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> QC_radar
#
# Renaming radar fields...
#
# DP products parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '44', 'ss': '24', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'cf_dir': './cf/', 'do_HID': True, 'do_mass': True, 'do_RC': True, 'do_tokay_DSD': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'output_cf': True, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD', 'SQ', 'FH', 'RC', 'DM', 'NW'], 'plot_images': True, 'plot_single': False, 'fields_to_plot': ['CZ', 'DM', 'NW', 'FH', 'RC', 'MW', 'MI'], 'plot_dir': './plots/', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> QC_radar
#
# Renaming radar fields...
#
# DP products parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '51', 'ss': '37', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'cf_dir': './cf/', 'do_HID': True, 'do_mass': True, 'do_RC': True, 'do_tokay_DSD': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'output_cf': True, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD', 'SQ', 'FH', 'RC', 'DM', 'NW'], 'plot_images': True, 'plot_single': False, 'fields_to_plot': ['CZ', 'DM', 'NW', 'FH', 'RC', 'MW', 'MI'], 'plot_dir': './plots/', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> QC_radar
#
# Renaming radar fields...
#
# DP products parameters:
#
# {'site': 'NPOL', 'scan_type': 'PPI', 'month': '10', 'day': '29', 'year': '2020', 'hh': '15', 'mm': '58', 'ss': '56', 'ref_field_name': 'CZ', 'phi_field_name': 'PH', 'zdr_field_name': 'DR', 'cf_dir': './cf/', 'do_HID': True, 'do_mass': True, 'do_RC': True, 'do_tokay_DSD': True, 'max_range': 200, 'max_height': 10, 'sweeps_to_plot': [0], 'output_cf': True, 'output_fields': ['DZ', 'CZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SD', 'SQ', 'FH', 'RC', 'DM', 'NW'], 'plot_images': True, 'plot_single': False, 'fields_to_plot': ['CZ', 'DM', 'NW', 'FH', 'RC', 'MW', 'MI'], 'plot_dir': './plots/', 'use_sounding': True, 'sounding_type': 'ruc_archive', 'sounding_dir': '/gvraid/trmmgv/Soundings/RUC_Soundings/', 'add_logos': True}
#
# Processing --> QC_radar
#
# Renaming radar fields...
# dict_keys(['DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD'])
#
#
# Calculating DP products:
#     Calculating Drop-Size Distribution...
# dict_keys(['DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD'])
#
#
# Calculating DP products:
#     Calculating Drop-Size Distribution...
# dict_keys(['DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD'])
#
#
# Calculating DP products:
#     Calculating Drop-Size Distribution...
# dict_keys(['DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD'])
#
# dict_keys(['DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD'])
#
#
# Calculating DP products:
#
# Calculating DP products:
#     Calculating Drop-Size Distribution...
# dict_keys(['DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD'])
#     Calculating Drop-Size Distribution...
#
#
# Calculating DP products:
#     Calculating Drop-Size Distribution...
# dict_keys(['DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD'])
#
#
# Calculating DP products:
#     Calculating Drop-Size Distribution...
# dict_keys(['DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD'])
#
#
# Calculating DP products:
#     Calculating Drop-Size Distribution...
# dict_keys(['DZ', 'VR', 'SW', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD'])
#
#
# Calculating DP products:
#     Calculating Drop-Size Distribution...
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_15UTC.txt
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_16UTC.txt
#     Interpolating sounding to radar structure...
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_16UTC.txt
#     Sounding file -->  NPOL_2020_1029_16UTC.txt
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_16UTC.txt
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_15UTC.txt
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_15UTC.txt
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_15UTC.txt
#     Interpolating sounding to radar structure...
#     Sounding file -->  NPOL_2020_1029_15UTC.txt
#     Add HID field to radar...
#     Add HID field to radar...
#     Add HID field to radar...
#     Add HID field to radar...
#     Add HID field to radar...
#     Add HID field to radar...
#     Add HID field to radar...
#     Add HID field to radar...
#     Add HID field to radar...
#     Calculating water and ice mass...
#     Calculating water and ice mass...
#     Calculating water and ice mass...
#     Calculating water and ice mass...
#     Calculating water and ice mass...
#     Calculating water and ice mass...
#     Calculating water and ice mass...
#     Calculating water and ice mass...
#     Calculating water and ice mass...
#     Calculating blended rainfall field...
#     Calculating blended rainfall field...
#     Calculating blended rainfall field...
#     Calculating blended rainfall field...
#     Calculating blended rainfall field...
#     Calculating blended rainfall field...
#     Calculating blended rainfall field...
#     Calculating blended rainfall field...
#     Calculating blended rainfall field...
# DP products complete.
#
# Plotting PPI images...
# DP products complete.
#
# Plotting PPI images...
# DP products complete.
#
# Plotting PPI images...
# DP products complete.
#
# Plotting PPI images...
# DP products complete.
#
# Plotting PPI images...
# DP products complete.
#
# Plotting PPI images...
# DP products complete.
#
# Plotting PPI images...
# DP products complete.
#
# Plotting PPI images...
# DP products complete.
#
# Plotting PPI images...
#   --> ./plots//NPOL_2020_1029_152953_7panel_sw00_PPI.png
#
# Removing unwanted output fields...
#
# CF FIELDS -->
# dict_keys(['DZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD', 'DM', 'NW', 'FH', 'RC'])
#
#   --> ./plots//NPOL_2020_1029_155137_7panel_sw00_PPI.png
#
# Removing unwanted output fields...
#
# CF FIELDS -->
# dict_keys(['DZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD', 'DM', 'NW', 'FH', 'RC'])
#
#   --> ./plots//NPOL_2020_1029_150051_7panel_sw00_PPI.png
#
# Removing unwanted output fields...
#
# CF FIELDS -->
# dict_keys(['DZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD', 'DM', 'NW', 'FH', 'RC'])
#
#   --> ./plots//NPOL_2020_1029_155856_7panel_sw00_PPI.png
#
# Removing unwanted output fields...
#
# CF FIELDS -->
# dict_keys(['DZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD', 'DM', 'NW', 'FH', 'RC'])
#
#   --> ./plots//NPOL_2020_1029_150751_7panel_sw00_PPI.png
#
# Removing unwanted output fields...
#
# CF FIELDS -->
# dict_keys(['DZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD', 'DM', 'NW', 'FH', 'RC'])
#
#   --> ./plots//NPOL_2020_1029_152237_7panel_sw00_PPI.png
#
# Removing unwanted output fields...
#
# CF FIELDS -->
# dict_keys(['DZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD', 'DM', 'NW', 'FH', 'RC'])
#
#   --> ./plots//NPOL_2020_1029_153709_7panel_sw00_PPI.png
#
# Removing unwanted output fields...
#
# CF FIELDS -->
# dict_keys(['DZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD', 'DM', 'NW', 'FH', 'RC'])
#
#   --> ./plots//NPOL_2020_1029_154424_7panel_sw00_PPI.png
#
# Removing unwanted output fields...
#
# CF FIELDS -->
# dict_keys(['DZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD', 'DM', 'NW', 'FH', 'RC'])
#
#   --> ./plots//NPOL_2020_1029_151520_7panel_sw00_PPI.png
#
# Removing unwanted output fields...
#
# CF FIELDS -->
# dict_keys(['DZ', 'VR', 'DR', 'KD', 'PH', 'RH', 'SQ', 'CZ', 'SD', 'DM', 'NW', 'FH', 'RC'])
#
# Output cfRadial --> ./cf//NPOL_2020_1029_152953_PPI.cf.gz
#
# Output cfRadial --> ./cf//NPOL_2020_1029_150051_PPI.cf.gz
#
# Output cfRadial --> ./cf//NPOL_2020_1029_155137_PPI.cf.gz
#
# Output cfRadial --> ./cf//NPOL_2020_1029_155856_PPI.cf.gz
#
# Output cfRadial --> ./cf//NPOL_2020_1029_150751_PPI.cf.gz
#
# Output cfRadial --> ./cf//NPOL_2020_1029_153709_PPI.cf.gz
#
# Output cfRadial --> ./cf//NPOL_2020_1029_152237_PPI.cf.gz
#
# Output cfRadial --> ./cf//NPOL_2020_1029_154424_PPI.cf.gz
#
# Output cfRadial --> ./cf//NPOL_2020_1029_151520_PPI.cf.gz
#
# Run time was 2.0 minute(s)
#
# Done.
